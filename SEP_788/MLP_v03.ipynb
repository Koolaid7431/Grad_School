# %% [markdown]
# # Attempt # 3
# - Duplicate class 1 in the dataset to match classes 0 & 1

# %% [markdown]
# ### Importing data

# %%
import numpy as np
import pandas as pd
preg = pd.read_csv('lab_results3.csv')

# %% [markdown]
# ### Data exploation:

# %%
preg.head()
#preg.describe()
#preg.shape
# Out:
#    pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0            6  0.743719       0.590164       0.353535  0.000000  0.500745
# 1            8  0.919598       0.524590       0.000000  0.000000  0.347243
# 2            0  0.688442       0.327869       0.353535  0.198582  0.642325
# 3            3  0.391960       0.409836       0.323232  0.104019  0.461997
# 4            2  0.989950       0.573770       0.454545  0.641844  0.454545
#
#    DiabetesPedigreeF  Age  Outcome
# 0           0.234415   50        1
# 1           0.253629   32        1
# 2           0.943638   33        1
# 3           0.072588   26        1
# 4           0.034159   53        1

# %% [markdown]
# ### Selection of data and labels

# %%
X = preg.drop('Outcome',axis=1) #axis is referring to row vs. column
y = preg['Outcome']
type(X)
X.shape
X.describe()
X.head()
# Out:
#    pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0            6  0.743719       0.590164       0.353535  0.000000  0.500745
# 1            8  0.919598       0.524590       0.000000  0.000000  0.347243
# 2            0  0.688442       0.327869       0.353535  0.198582  0.642325
# 3            3  0.391960       0.409836       0.323232  0.104019  0.461997
# 4            2  0.989950       0.573770       0.454545  0.641844  0.454545
#
#    DiabetesPedigreeF  Age
# 0           0.234415   50
# 1           0.253629   32
# 2           0.943638   33
# 3           0.072588   26
# 4           0.034159   53

# %% [markdown]
# ### Train Test Split
# As Fundamental step you need to split data to train and test; to do so, you can levelrage SciKit Learn's train_test_split function from model_selection. Feel free to check it out here:
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split
#help(train_test_split)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# ### Data Preprocessing
# Standardize features by removing the mean and scaling to unit variance
#
# The standard score of a sample x is calculated as z = (x - u) / s
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
from sklearn.preprocessing import StandardScaler
#help(StandardScaler)

# %%
scaler = StandardScaler() #normalizing the data

# %%
# Fit only to the training data
print(np.mean(X_train, axis=0))
scaler.fit(X_train)
help(scaler.fit)
print(scaler.mean_)
# Out:
# pregnancies           4.024444
# Glucose               0.627080
# BloodPressure         0.567359
# SkinThickness         0.211852
# Insulin               0.096481
# BMI                   0.487038
# DiabetesPedigreeF     0.178024
# Age                  33.933333
# dtype: float64
# Help on method fit in module sklearn.preprocessing._data:
#
# fit(X, y=None) method of sklearn.preprocessing._data.StandardScaler instance
#     Compute the mean and std to be used for later scaling.
#
#     Parameters
#     ----------
#     X : {array-like, sparse matrix}, shape [n_samples, n_features]
#         The data used to compute the mean and standard deviation
#         used for later scaling along the features axis.
#
#     y
#         Ignored
#
# [ 4.02444444  0.62707984  0.56735883  0.21185185  0.09648148  0.48703759
#   0.17802448 33.93333333]

# %%
# Now apply the transformations to the data:
X_train 
X_train1= scaler.transform(X_train)
X_test 
X_test1= scaler.transform(X_test)

print('Xtrain:', X_train)
print('Xtrain shape:', X_train.shape)
print('Xtrain1:', X_train1)
print('Xtrain1 shape:', X_train1.shape)

print('Xtest:', X_test)
print('Xtest1:', X_test1)

print('Xtrain mean')
print(np.mean(X_train, axis = 0))
print('Xtrain1 mean')
print(np.mean(X_train1, axis = 0))
print('Xtest mean')
print(np.mean(X_test, axis = 0))
print('Xtest1 mean')
print(np.mean(X_test1, axis = 0))

#running this block again even after resetting the kernel seems to be reapplying the transform.
''''
    [-1.59936017e+00 -2.82274816e+13 -2.51272754e+13 -6.24895858e+12
     -1.40060281e+14 -4.44668650e+15 -5.44836963e+13 -3.08555095e+00]
    [-1.59936017e+00 -2.94436316e+13 -2.50638734e+13 -4.13697394e+12
     -7.40447989e+13 -4.80290837e+15 -8.48380856e+13 -3.08555095e+00]

    # the above block of print out is after 4 reattempts
'''
# Out:
# Xtrain:      pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 803            4  0.673367       0.590164       0.000000  0.000000  0.354694
# 208            7  0.753769       0.639344       0.292929  0.148936  0.524590
# 161            3  0.648241       0.524590       0.292929  0.135934  0.393443
# 456            2  0.603015       0.622951       0.373737  0.124113  0.591654
# 629            1  0.487437       0.573770       0.404040  0.000000  0.567809
# ..           ...       ...            ...            ...       ...       ...
# 956            4  0.663317       0.000000       0.000000  0.000000  0.490313
# 131            9  0.763819       0.639344       0.343434  0.202128  0.509687
# 728            2  0.648241       0.000000       0.000000  0.000000  0.573770
# 84             0  0.889447       0.491803       0.292929  0.565012  0.515648
# 844            5  0.814070       0.852459       0.000000  0.000000  0.561848
#
#      DiabetesPedigreeF  Age
# 803           0.084970   60
# 208           0.262169   54
# 161           0.060205   28
# 456           0.058497   29
# 629           0.059778   30
# ..                 ...  ...
# 956           0.095645   23
# 131           0.347993   33
# 728           0.096499   41
# 84            0.424424   21
# 844           0.031170   52
#
# [900 rows x 8 columns]
# Xtrain shape: (900, 8)
# Xtrain1: [[-0.00699477  0.28340645  0.13773015 ... -1.13264426 -0.62000703
#    2.21537746]
#  [ 0.85145477  0.77569268  0.43475204 ...  0.32138969  0.56064263
#    1.70544403]
#  [-0.29314462  0.129567   -0.25829904 ... -0.80102249 -0.78501349
#   -0.5042675 ]
#  ...
#  [-0.57929447  0.129567   -3.42653255 ...  0.74229426 -0.54319368
#    0.60058826]
#  [-1.15159416  1.60642569 -0.45631363 ...  0.24486158  1.64171944
#   -1.09918984]
#  [ 0.27915507  1.14490735  1.72184691 ...  0.64025678 -0.97846934
#    1.53546622]]
# Xtrain1 shape: (900, 8)
# Xtest:      pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 198            2  0.592965       0.655738       0.000000  0.000000  0.639344
# 25             8  0.884422       0.737705       0.343434  0.354610  0.502235
# 540            6  0.537688       0.721311       0.000000  0.000000  0.548435
# 585            6  0.773869       0.606557       0.323232  0.228132  0.436662
# 698            2  0.603015       0.442623       0.000000  0.000000  0.399404
# ..           ...       ...            ...            ...       ...       ...
# 464            4  0.648241       0.491803       0.121212  0.273050  0.409836
#  -5.92118946e-17  8.09229227e-17  2.36847579e-17  3.16783636e-16]
# Xtest mean
# pregnancies           4.610000
# Glucose               0.663216
# BloodPressure         0.577541
# SkinThickness         0.212121
# Insulin               0.139149
# BMI                   0.495395
# DiabetesPedigreeF     0.172152
# Age                  35.230000
# dtype: float64
# Xtest1 mean
# [ 0.16755663  0.22125531  0.06149453  0.00163857  0.31919072  0.07152543
#  -0.03912739  0.11020228]
# "'\n    [-1.59936017e+00 -2.82274816e+13 -2.51272754e+13 -6.24895858e+12\n     -1.40060281e+14 -4.44668650e+15 -5.44836963e+13 -3.08555095e+00]\n    [-1.59936017e+00 -2.94436316e+13 -2.50638734e+13 -4.13697394e+12\n     -7.40447989e+13 -4.80290837e+15 -8.48380856e+13 -3.08555095e+00]\n\n    # the above block of print out is after 4 reattempts\n"

# %% [markdown]
# ### Model Training
#
# Now it is time to train our model. Import  estimator (the Multi-Layer Perceptron Classifier model) from the neural_network library of SciKit-Learn:

# %%
from sklearn.neural_network import MLPClassifier
#help(MLPClassifier)

# %% [markdown]
# Next we create an instance of the model,we will only define the hidden_layer_sizes.
# For that we pass in a tuple consisting of the number of neurons you want at each layer.

# %%
#current highest
#mlp = MLPClassifier(activation='tanh', batch_size= 20, hidden_layer_sizes=(20,10,1),max_iter=2500, learning_rate='constant',solver='adam')

# %%
#mlp = MLPClassifier(activation='tanh', batch_size= 20, hidden_layer_sizes=(20,10,1),max_iter=2500, learning_rate='adaptive',solver='adam')
#max_iter=500

mlp = MLPClassifier(activation='tanh', batch_size= 400, hidden_layer_sizes=(20,10,1),max_iter=3000, learning_rate='constant', learning_rate_init=0.0005,solver='adam')

# %% [markdown]
# Now that the model has been made we can fit the training data to our model, remember that this data has already been processed and scaled:

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size=400, beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(20, 10, 1), learning_rate='constant',
#               learning_rate_init=0.0005, max_fun=15000, max_iter=3000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %% [markdown]
# Play around with parameters and discover what effects they have on your model!
#
# ## Predictions and Evaluation
#
# Now that we have a model it is time to use it to get predictions! We can do this simply with the predict() method off of our fitted model:

# %%
predictions = mlp.predict(X_test)

# %% [markdown]
# Now we can use SciKit-Learn's built in metrics such as a classification report and confusion matrix to evaluate how well our model performed:

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
#help(confusion_matrix)
# Out:
# [[37 11]
#  [11 41]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77        48
#            1       0.79      0.79      0.79        52
#
#     accuracy                           0.78       100
#    macro avg       0.78      0.78      0.78       100
# weighted avg       0.78      0.78      0.78       100

# %%
len(mlp.coefs_)
# Out:
# 4

# %%
len(mlp.coefs_[0])
#mlp.coefs_
#mlp.coefs_[0]
# Out:
# 8

# %%
len(mlp.intercepts_[0])
#mlp.intercepts_
# Out:
# 20

# %% [markdown]
# To extract the MLP weights and biases after training your model, you use its public attributes **coefs_** and **intercepts_**.
#
# **coefs_** is a list of weight matrices, where weight matrix at index i represents the weights between layer i and layer i+1.
#
# **intercepts_** is a list of bias vectors, where the vector at index i represents the bias values added to layer i+1.
